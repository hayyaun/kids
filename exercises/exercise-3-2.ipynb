# %% [markdown]
# <div dir="rtl">
#
# ## تمرین عدد اول
#
# بعد از حل این مینی تمرین ها شما در نهایت تمرین تشخیص عدد اول رو حل کردید!
#
# لطفا برنامه ای بنویسید که:
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ۱. یک عدد رو از کاربر بگیره و تقسیم باقی مونده ش به ۲ رو بنویسه
#
# > برای اینکه باقی مونده یک عدد به یک عدد دیگه رو پیدا کنید از علامت % استفاده می کنیم
# > صورت در سمت چپ و مخرج در سمت راست قرار می گیره و نتیجه نهایی میشه باقی مونده. مثلا:
#
# </div>
#
# > 5 % 2 == 1

# %%
# TODO 1

# %% [markdown]
# <div dir="rtl">
#
# ۲. یک عدد رو از کاربر بگیره و باقی مونده اش رو به اعداد ۲ تا ۱۰ بنویسه.
#
# </div>

# %%
# TODO 2

# %% [markdown]
# <div dir="rtl">
#
# ۳. عدد n رو از کاربر بگیره و باقی مونده اش به اعداد ۲ تا n رو بنویسه
#
# </div>

# %%
# TODO 3

# %% [markdown]
# <div dir="rtl">
#
# ۴. یک عدد از کاربر بگیره و بگه **آیا** باقی مونده اش به اعداد ۲ تا n جایی صفر شده یا نشده
#
# > برای اینکه کلمه «آیا» رو وارد کد کنیم از if استفاده میکنیم که درس سوم خوندیم
#
# </div>

# %%
# TODO 4

# %% [markdown]
# <div dir="rtl">
#
# ۵. یه متغیر شمارنده به اسم count بسازه و مقدارش رو برابر صفر قرار بده
# دقیقا مثل تمرین قبل: عدد n رو از کاربر بگیره و ببینه آیا باقی مونده اش به اعداد ۲ تا n جایی صفر شده یا نشده
# اگه جایی باقی مونده اش به عدد حلقه که همون i هست صفر شده باشه: یکی به عدد شمارنده اضافه می کنیم
# `count += 1`
# بعد که از حلقه خارج شدیم: میگیم که اگه به هیچ عددی بخش پذیر نبود `count == 0` بنویسه که عدد اوله.
# در غیر این صورت عدد اول نیست!
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# > #### شمارنده 🔢
# >
# > شمارنده چیه؟ - اینم سواله مومن؟ تسبیح ندیدی؟ مثه تسبیح کارش اینه بشماره
# > مثلا توی حلقه که با while می نوشتیم یادته یه متغیر `i = 0` در نظر می گرفتیم که هی زیاد میکردیمش؟
# > آفرین! دقیقا به اون میگن شمارنده
#
# </div>

# %%
# TODO 5

# %% [markdown]
# ‍<div dir="rtl">
#
# ۶. یک پرچم به اسم is_prime بسازه و مقدارش رو برابر True بذاره
# دقیقا مثل تمرین قبل: عدد n رو از کاربر بگیره و ببینه آیا باقی مونده اش به اعداد ۲ تا n جایی صفر شده یا نشده ‍
# اگه جایی صفر شده باشه یعنی عدد اول نیست و پرچم is_prime رو برابر False می کنیم. در غیر این صورت کاری به پرچم دست نمیزنیم!
# بعد که از حلقه بیرون اومدیم: میگیم اگه پرچم True بود بنویسه عدد اوله.
# در غیر این صورت هم بنویسه عدد اول نیست
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# > #### پرچم 🚩
# >
# > پرچم چیه؟ - پرچم هیچی نیست. یه متغیر بولین (آره/نه) هست.
# > خب حالا به چه دردی میخوره؟ - وضعیت یه اتفاق رو نشون میده
# > ها؟ - کمک داور رو دیدی لب خط فوتبال وای میسه وقتی کورنر شد پرچمشو بالا میگیره؟
# > اینجام همینجوریه مثلا ما فرض میکنیم عدد اول هست (پرچم پایینه).
# > ولی خدا نکنه خطایی از عدد n سر بزنه و متوجه شیم بر چیزی بخش پذیره.
# > اون جاست که پرچم رو بالا میبریم و همه ی عالم میفهمن که این عدد اول نیست!
#
# </div>

# %%
# 1. Get a number from user in Terminal
# 2. Loop to see if it divides by any number

# TODO 6

# %% [markdown]
# <div dir="rtl">
#
# تبریک میگم شما مساله تشخیص عدد اول رو حل کردید 🥳🥳
#
# > اگه براتون سواله که چرا اگه باقی مونده صفر نبود پرچم رو دست نمیزنیم میتونید تست کنید و نتیجه ش رو آنالیز کنید
#
# </div>
